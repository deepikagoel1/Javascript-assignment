# %% [markdown]
# # Basic Python Programming

# %% [markdown]
# __keyword__ : Special Names that are already present in Python.

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print(keyword.iskeyword('for'))
# Out:
# True

# %%
help(keyword)
# Out:
# Help on module keyword:
#
# NAME
#     keyword - Keywords (from "Grammar/Grammar")
#
# MODULE REFERENCE
#     https://docs.python.org/3.8/library/keyword
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This file is automatically generated; please don't muck it up!
#
#     To update the symbols in this file, 'cd' to the top directory of
#     the python source tree and run:
#
#         python3 -m Parser.pgen.keywordgen Grammar/Grammar                                       Grammar/Tokens                                       Lib/keyword.py
#
#     Alternatively, you can run 'make regen-keyword'.
#
# FUNCTIONS
#     iskeyword = __contains__(...) method of builtins.frozenset instance
# ...

# %%
'deepika' in keyword.kwlist
# Out:
# False

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# /Users/sumitkumarshukla/opt/anaconda3/lib/python3.8/site-packages/IPython/kernel/__init__.py:12: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   warn("The `IPython.kernel` package has been deprecated since IPython 4.0."
# WARNING: AstropyDeprecationWarning: The private astropy._erfa module has been made into its own package, pyerfa, which is a dependency of astropy and can be imported directly using "import erfa" [astropy._erfa]
# /Users/sumitkumarshukla/opt/anaconda3/lib/python3.8/pkgutil.py:92: MatplotlibDeprecationWarning:
# The matplotlib.compat module was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   __import__(info.name)
# ...

# %%
print('Hello Students! ') # prinitng the line
# Out:
# Hello Students!

# %%
#print(5)

# %% [markdown]
# __Comment :__ Programmer Co-herent statements, non - executable lines

# %%
# This is a Single line Comment 
# This is 
# a Multi Line 
# Comment

# %% [markdown]
# __Variable__: reserved memory locations to store values

# %%
A = 20 
B = 20.4 
C = 'Hello'

# %%
print(A, B, C)
# Out:
# 20 20.4 Hello

# %% [markdown]
# __Python Numbers__ : Integer, Float, Complex, random numbers

# %%
Integer = 'Whole Numbers' # 1, -2, 0, -6, 5, 
Float   = 'Real Numbers' # 0.4, 1/2, -3.4
Complex = 'Real Numbers + imaginary Numbers' # a + bj

# %%
a,b,c = 2, 3.4, 3 - 4j

# %%
type(a), type(b), type(c)
# Out:
# (int, float, complex)

# %%
c.real, c.imag
# Out:
# (3.0, -4.0)

# %% [markdown]
# ### Random Numbers

# %%
import random

# %%
print(dir(random))
# Out:
# ['BPF', 'LOG4', 'NV_MAGICCONST', 'RECIP_BPF', 'Random', 'SG_MAGICCONST', 'SystemRandom', 'TWOPI', '_Sequence', '_Set', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_accumulate', '_acos', '_bisect', '_ceil', '_cos', '_e', '_exp', '_inst', '_log', '_os', '_pi', '_random', '_repeat', '_sha512', '_sin', '_sqrt', '_test', '_test_generator', '_urandom', '_warn', 'betavariate', 'choice', 'choices', 'expovariate', 'gammavariate', 'gauss', 'getrandbits', 'getstate', 'lognormvariate', 'normalvariate', 'paretovariate', 'randint', 'random', 'randrange', 'sample', 'seed', 'setstate', 'shuffle', 'triangular', 'uniform', 'vonmisesvariate', 'weibullvariate']

# %% [markdown]
# ### range[start, stop, step]
#
# __range[n,m,s]__ = elements from n to m - 1 in the interval of s
#
# range(0, 5) = 0, 1, 2, 3, 4
#
# range(0, 10, 2) = 0, 2, 4, 6, 8

# %%
range(0, 5)
# Out:
# range(0, 5)

# %%
print(random.randrange(1, 5))
# Out:
# 1

# %% [markdown]
# ### Generating OTPs

# %%
print('G- '+ str(random.randrange(123456, 987654)) + ' is your One Time Google Verification Code.')
# Out:
# G- 968690 is your One Time Google Verification Code.

# %%
a = input('G- ')
# Out:
# G- 968690

# %%
print(1 +  2.0)
# Out:
# 3.0

# %% [markdown]
# __String__ = 'anything what you defined in between quotes'

# %%
print('str' + '.')
# Out:
# str.

# %%
str(5)
# Out:
# '5'

# %%
print(str(random.randrange(123456, 987654)) + ' is your Facebook/Instagram Password Reset Code.')
# Out:
# 714673 is your Facebook/Instagram Password Reset Code.

# %% [markdown]
# ### Passwords

# %%
lower = 'abcdefghijklmnopqrstuvwxyz'
upper = lower.upper()
numbers = '0123456789'
charact = '!@#$%^&*()'

# %%
''.join(random.sample(lower+ upper+numbers + charact, 8))
# Out:
# '0f5UaKAl'

# %%
lower+ upper+numbers + charact
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!@#$%^&*()'

# %%
''.join(random.sample(lower,9))
# Out:
# 'wlraqfnvt'

# %%
lower
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
len(lower)
# Out:
# 26

# %%
type(lower)
# Out:
# str

# %%
help(str.join)
# Out:
# Help on method_descriptor:
#
# join(self, iterable, /)
#     Concatenate any number of strings.
#
#     The string whose method is called is inserted in between each given string.
#     The result is returned as a new string.
#
#     Example: '.'.join(['ab', 'pq', 'rs']) -> 'ab.pq.rs'

# %%
'-'.join(['wlr','aqf','nvt'])
# Out:
# 'wlr-aqf-nvt'

# %% [markdown]
# ### Input Statement

# %% [markdown]
# raw_input = Python 2, input = Python 3

# %%
print(random.__doc__)
# Out:
# Random variable generators.
#
#     integers
#     --------
#            uniform within range
#
#     sequences
#     ---------
#            pick random element
#            pick random sample
#            pick weighted random sample
#            generate random permutation
#
#     distributions on the real line:
#     ------------------------------
#            uniform
#            triangular
#            normal (Gaussian)
#            lognormal
#            negative exponential
#            gamma
#            beta
#            pareto
#            Weibull
#
#     distributions on the circle (angles 0 to 2pi)
#     ---------------------------------------------
#            circular uniform
#            von Mises
#
# General notes on the underlying Mersenne Twister core generator:
#
# * The period is 2**19937-1.
# * It is one of the most extensively tested generators in existence.
# * The random() method is implemented in C, executes in a single Python step,
# ...

# %%
a = input('Enter Name: ')
# Out:
# Enter Name: Sumit Kumar Shukla

# %%
print(a)
# Out:
# Sumit Kumar Shukla

# %%
b = int(input('Enter number: '))
# Out:
# Enter number: 5

# %%
type(b)
# Out:
# int

# %%
c = float(input('Enter a number: '))
# Out:
# Enter a number: 45

# %%
c
# Out:
# 45.0

# %%
d = eval(input('Enter complex'))
# Out:
# Enter complex3+ 4j

# %%
d
# Out:
# (3+4j)

# %%
d.real, d.imag
# Out:
# (3.0, 4.0)

# %%
eval(input())
# Out:
# 5
# 5

# %%
eval('3'*2)
# Out:
# 33

# %% [markdown]
# ### String Replication

# %%
'string ' * 4
# Out:
# 'string string string string '

# %%
'String' + '.'
# Out:
# 'String.'

# %%
a = 'ice'
a+= 'cream'
a
# Out:
# 'icecream'

# %%
import sys 
sys.version
# Out:
# '3.8.8 (default, Apr 13 2021, 12:59:45) \n[Clang 10.0.0 ]'
